# %%
#-*- coding: utf-8 -*-
import MySQLdb
import codecs

# 打开数据库连接
db = MySQLdb.connect("admin.citypet.cn","pocketpet","3MjdvUuXqxca6cbc","goldminer",charset="utf8")

# 使用cursor()方法获取操作游标 
cursor = db.cursor()

for line in codecs.open("/Users/abing/Downloads/bb.txt", "r", "utf8").readlines():
    parts = line.strip().split("\t")
    
#     print(parts[1])
#     sql = "alter table  cashflow_statement add %s double comment '%s'" % (parts[0], parts[1])
#     print(parts)
#     cursor.execute(sql)

# for line in codecs.open("/Users/abing/Downloads/上市公司列表.csv", "r", "utf8").readlines():
#     parts = line.strip().split(",")
#     code = parts[0].strip()
#     name = parts[1].strip()
#     pubdate = parts[7].strip()
#     totalstock = parts[8].strip()
#     c_stock = parts[9].strip()
#     industry = parts[18].strip()
#     if code == "公司代码":
#         continue
# #     print(parts[1])
#     sql = "insert into stocks (code, name, pub_date, industry, total_stock, circulation_stock, exchange) VALUE ('%s', '%s', '%s', '%s',  %s, %s, 2);" % \
#     (code, name, pubdate, industry, totalstock, c_stock)
#     print(sql)
#     cursor.execute(sql)
#     db.commit()

# 关闭数据库连接
db.close()
# Out:
# insert into stocks (code, name, pub_date, industry, total_stock, circulation_stock, exchange) VALUE ('000001', '平安银行', '1991-04-03', 'J 金融业',  17170411366, 16918003290, 2);
# insert into stocks (code, name, pub_date, industry, total_stock, circulation_stock, exchange) VALUE ('000002', '万  科Ａ', '1991-01-29', 'K 房地产',  9724196533, 9715170043, 2);
# insert into stocks (code, name, pub_date, industry, total_stock, circulation_stock, exchange) VALUE ('000004', '国农科技', '1990-12-01', 'C 制造业',  83976684, 83013184, 2);
# insert into stocks (code, name, pub_date, industry, total_stock, circulation_stock, exchange) VALUE ('000005', '世纪星源', '1990-12-10', 'N 公共环保',  1058536842, 951222460, 2);
# insert into stocks (code, name, pub_date, industry, total_stock, circulation_stock, exchange) VALUE ('000006', '深振业Ａ', '1992-04-27', 'K 房地产',  1349995046, 1348307972, 2);
# ...
